# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Michael Jay**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I love to analyze data to help formulate informed decisions.*

# %% [markdown]
# ### The code will draw a basic parabola

# %%
from matplotlib.pyplot import *
from numpy import *
x=linspace(-1,1,5000)
y=x**2
plot(x,y)
xlabel("x axis")
ylabel("y axis")
print(x)
show()
# Out:
# [-1.         -0.99959992 -0.99919984 ...  0.99919984  0.99959992
#   1.        ]

# %% [markdown]
# Testing | Different | Styles
# --- | --- | ---
# *Italic* | `typo` | **bold**
# 1 | 2 | 3
#
# My favorite search engine is [Google](https://google.com).
